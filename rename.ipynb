# %% [markdown]
# Name: Patil Amol Sanjiv
# Roll no: 210711

# %% [markdown]
# This code was written to rename a few files in the dataset so that files are named and processed in order

# %%
import os

# Define the root directory where the subfolders are located
root_directory = r'C:\Storage\me\IIT\sem 7\ee798\paper2\ascertain\EEGData\EEGData'

# Walk through the directory
for subdir, _, files in os.walk(root_directory):
    print(f'Checking in: {subdir}')  # Print current directory being checked
    for file in files:
        print(f'Found file: {file}')  # Print each file found
        if file == 'EEG_Clip9.mat':
            # Create the new filename
            new_name = 'EEG_Clip09.mat'
            # Construct full file paths
            old_file_path = os.path.join(subdir, file)
            new_file_path = os.path.join(subdir, new_name)
            # Rename the file
            os.rename(old_file_path, new_file_path)
            print(f'Renamed: {old_file_path} to {new_file_path}')
# Out:
# Checking in: C:\Storage\me\IIT\sem 7\ee798\paper2\ascertain\EEGData\EEGData
# Checking in: C:\Storage\me\IIT\sem 7\ee798\paper2\ascertain\EEGData\EEGData\Movie_P01
# Found file: EEG_Clip01.mat
# Found file: EEG_Clip02.mat
# Found file: EEG_Clip03.mat
# Found file: EEG_Clip04.mat
# Found file: EEG_Clip05.mat
# Found file: EEG_Clip06.mat
# Found file: EEG_Clip07.mat
# Found file: EEG_Clip08.mat
# Found file: EEG_Clip10.mat
# Found file: EEG_Clip11.mat
# Found file: EEG_Clip12.mat
# Found file: EEG_Clip13.mat
# Found file: EEG_Clip14.mat
# Found file: EEG_Clip15.mat
# Found file: EEG_Clip16.mat
# Found file: EEG_Clip17.mat
# Found file: EEG_Clip18.mat
# Found file: EEG_Clip19.mat
# Found file: EEG_Clip20.mat
# Found file: EEG_Clip21.mat
# Found file: EEG_Clip22.mat
# Found file: EEG_Clip23.mat
# Found file: EEG_Clip24.mat
# Found file: EEG_Clip25.mat
# Found file: EEG_Clip26.mat
# Found file: EEG_Clip27.mat
# Found file: EEG_Clip28.mat
# Found file: EEG_Clip29.mat
# ...
